# %%
### Dictionaries

# Definicion

my_dict=dict()
my_other_dict = {}

print(type(my_dict))
print(type(my_other_dict)) #items: es la parejita(variable y contenido)  keys:variable  values:contenido

my_other_dict = {"Nombre": "Joselin",
                 "Apellido": "Ruiz", "Edad": 17, 1: "Python"}

my_dict = {
     "Nombre": "Joselin",
     "Apellido": "Ruiz",
     "Edad": 17,
     "Lenguajes": {"Python", "Swift", "Kotlin"},
      1: 1.57
 }

print(my_other_dict)
print(my_dict)

print(len(my_other_dict))  #len=longitud
print(len(my_dict))


 # Busqueda

print(my_dict[1])
print(my_dict["Nombre"])

print("Ruiz" in my_dict)
print("Apelido" in my_dict)


# Insercion (insertar o agregar) para agregar es la variable y su valor

my_dict["Calle"] = "Calle Garcia"
print(my_dict)

# Actualizacion (cambiamos el nombre que ya habia )

my_dict["Nombre"] = "Juan"
print(my_dict["Nombre"])

# Eliminacion

del my_dict["Calle"]
print(my_dict)

# Otras operaciones

print(my_dict_items)
print(my_dict_k)
print(my_dict.values())

my_list = ["Nombre", 1, "Piso"]

my_new_dict = dict.fromkeys((my_list))
print(my_new_list)
my_new_dict = dict.fromkeys(("Nombre", 1, "Piso"))
print((my_new_dict))
my_new_dict = dict.fromkeys(my_dict)
print(my_new_dict)
my_new_dict = dict.fromkeys(my_dict, "Ruiz") #odas la valus las remplazamos por garcia
print((my_new_print))

my_values = my_new_dict.values()
print(type(my_values))

print(my_new_dict.values())
print(list(dict.fromkeys(list(my_new_dict.values())).keys()))
print(tuple(my_new_dict))
print(set(my-new_dict))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-a463468c238d> in <cell line: 5>()
#       3 # Definicion
#       4
# ----> 5 my_dict=dict()
#       6 my_other_dict = {}
#       7
#
# TypeError: 'dict' object is not callable
