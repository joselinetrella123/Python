# %%
my_string = "Mi string"
my_other_string = "Mi otro String"

print(len(my_string))
print(len(my_other_string))
print(my_string + "" + my_other_string)

my_new_line_string = "Este es un string/ncon salto de linea"
print(my_new_line_string)

my_tab_string = "\+Este es un Sting con tabulacion"
print(my_tab_string)

my_scape_string = "\\+Este  es un Sting \\n escapado"
print(my_scape_string)


 # Formateo
 name, surname, age = "Joselin", "Ruiz", 16
 print("Mi nombre  es {} {} y ,y edad es {}". format(name, surname, age ))
 print("Mi nombre es %s %s y mi edad es %d" % (name, surname, age))
 print("Mi nombre es "+name+""+surname+ "y mi edad es "+ str(age))
 print(f"Mi nombre es {name} {surname} y mi edad es {age}")


 # Desempaquetado de caracteres
  language = "python"
  a,b,c,d,e,f = language
  print(a)
  print(e)


  # Division
  language_slice = language[1:3]
  print(language_slice)

  language_slice = language[1:]
  print(language_slice)

  language_slice =lenguage[-2]
  print(language_slice)

  language_slice = language[0:6:2]
  print(language_slice)

  # Reverse
  reserved_lenguage = lenguage [::-1]
  print(reserved_languague)

# Funciones del lenguaje
# print (language.capitalize())
# print (language.upper())
# print (language.count("+"))
# print ( language.isnumeric())
# print (language "1".isnumeric())
# print (language.lower())
# print (language.lower().isnupper())
# print (language.starts with("Py"))
# print ("PY" == "py") # No es lo mismo
# Out:
#   File "<ipython-input-1-cc822fce2371>", line 19
#     name, surname, age = "Joselin", "Ruiz", 16
#     ^
# IndentationError: unexpected indent
