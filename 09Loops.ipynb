# %%
### Loops ###

#While

my_condition = 0

while my_condition < 10:
     print(my_condition)
     my_condition += 2
else: # Es opcional
    print("Mi condicion es igual o menor que 10")

print("La ejecucion continua")

while my_condition < 20:
   my_condition += 1
   if my_condition == 15:
      print("Se detiene la ejecucion")


# For

my_list = [35,24,62,52,30,30,17]

for element in my_list:
    print(element)

my tuple = (17,155, "Joselin", "Ruiz", "Joss")

for element in my_tuple:
    print(element)

my_set = {"Joselin", "Ruiz", 17}

for element in my_set:
    print(element)

my_dict ={"nombre": "Joselin", "Apellido": "Ruiz", "Edad": 35,1: "Python"}

for element in my_dict:
    print(element)
    if element == "Edad":
       break

else:
   print("El bluce for para diccionario ha finalizado")

print("La ejecucion continua")

for elemnet in my_dict:
    print(element)
    if element == "Edad":
        break

else:
   print("El bluce for para diccionario ha finalizado")

print("La ejecucion continua")

for element in my_dict:
    print(element)
    if element == "Edad":
       continue
    print("Se ejecuta")
else
   print("El bluce for para diccionario ha finalizado")
