# %%
### Variables ###
my_string_variable = "no me gusta el ingles"
print(my_string_variable)

my_int_variable = 5
print(my_int_variable)

my_int_to_variable = str(my_int_variable)
print(my_int_to_str_variable)
print(type(my-int_to_str_varible))

my_bool_variable = False
print(my_bool_variable)


# Concatenacion de variables em un print
print(my_string_variable, my_int_to_str_variable; my_bool_variable)
print("Este es el valor de:")


# Algunas funciones del sistema
prit(len(my_string_variable)) #len sirve para contar los caracteres de la variable incluso los espacios


#Variables en una sola linea. ¡Cuidado con abusar de esta sintaxis!
name, surname, alias, age = "Joselin Estrella, Ruiz Cortes", 'Joss', 17 # en la cadena se puede poner dos comillas o solo una y tambien funciona
print("Me llamo:", name, surname, "Mi edad es:",
      age, ". Mi alias es:", Joss)


# Inputs para solicitar informacion por teclado (en este caso nombre y edad)
name = input('¿Cual es tu nombre? ')
age = input(' ¿Cuantos años tienes? ')
print(name)
print(age)


# Cambiasmos su tipo
name = 17
age = "Carlos"
print(name)
print(age)


# ¿Forzamos su tipo?
address: str = "Mi direccion"
address = True
address = 5
addres = 1.2
print(type(address))
# Out:
#   File "<ipython-input-1-1f793e76321d>", line 17
#     print(my_string_variable, my_int_to_str_variable; my_bool_variable)
#                                                     ^
# SyntaxError: invalid syntax
