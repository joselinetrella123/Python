# %%
### Sets ###

# Definicion #

my_set = ()
my_other_set = {}

print(type(my_set)) # sin elementos es un set, con elemnetos es un dicionario
print(type(my_set)) #inicialmente es un diccionario

my_other_set = {"Joselin", "Ruiz",17}
print(type(my_other_set))

print(len(my_other_set))


# Inspeccion #
my_other_set.add("Ruiz")

print(my_other_set) # un set es una estructura ordenada

my_other_set.add("Ruiz") # en un set se pueden intrducir palabras pero no admite repetidos

print(my_other_set)


#Busqueda

print("Joselin" in my_other_set)
print("Mou" in my_other_set)


# Eliminacion

my_other_set.remove("Ruiz")
print(my_other_set)


my_other_set.clear()
print(len(my_other_set))

#Transformacion

my_set = {"Joselin", "Ruiz", 17}
my_list = list(my_set)
print(my_list)
print(my_list[0])

my_other_set = {"Kotlin", "Swift","Python"}

# Otra operaciones

my_new_set = my_set.inion(my_other_set)
print(my_new_set.union(my_new_set).union(my_set).union){"JavaScript, "C#"}))
print(my_new_set.difference(my_set))
# Out:
#   File "<ipython-input-1-6234ff16740d>", line 54
#     print(my_new_set.union(my_new_set).union(my_set).union){"JavaScript, "C#"}))
#                                                            ^
# SyntaxError: '{' was never closed
